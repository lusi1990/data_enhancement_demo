# %%
import imageio

import imgaug as ia
import ipyplot
import imgaug.augmenters as iaa

# %%
input_img = imageio.imread_v2('./class_image/UFO.jpg')

# %% [markdown]
# # Vertical Flip

# %%
hflip = iaa.Fliplr(p=1.0)
vflip = iaa.Flipud(p=1.0)

input_hf = hflip.augment_image(input_img)
input_vf = vflip.augment_image(input_img)
input_hvf = vflip.augment_image(input_hf)
images_list = [input_img, input_hf, input_vf, input_hvf]
labels = ['Original', 'Horizontally flipped', 'Vertically flipped', 'Horizontally Vertically flipped']
ipyplot.plot_class_representations(images_list, labels)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WeDBH9PSbMYzsftJBAS2fJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WeDBH9PSbMYzsftJBAS2fJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WeDBH9PSbMYzsftJBAS2fJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WeDBH9PSbMYzsftJBAS2fJ:checked ~ #ipyplot-html-viewer-textarea-WeDBH9PSbMYzsftJBAS2fJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WeDBH9PSbMYzsftJBAS2fJ:checked + #ipyplot-html-viewer-label-WeDBH9PSbMYzsftJBAS2fJ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-WeDBH9PSbMYzsftJBAS2fJ">
#         <label id="ipyplot-html-viewer-label-WeDBH9PSbMYzsftJBAS2fJ" for="ipyplot-html-viewer-toggle-WeDBH9PSbMYzsftJBAS2fJ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-WeDBH9PSbMYzsftJBAS2fJ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-QrB46iokUuikgYmKgzkfdi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-QrB46iokUuikgYmKgzkfdi">
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-6Qf9cAvfULpxVvN6Bkarz6" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-6Qf9cAvfULpxVvN6Bkarz6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-5ixvXtriKAdgjYt5i8mMZ4" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-5ixvXtriKAdgjYt5i8mMZ4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-DCMDiiXRcQYjfTTVUgqitc" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-DCMDiiXRcQYjfTTVUgqitc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-TPL7grkioNy3XqyJLHwZt2" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-TPL7grkioNy3XqyJLHwZt2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-QrB46iokUuikgYmKgzkfdi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-QrB46iokUuikgYmKgzkfdi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-QrB46iokUuikgYmKgzkfdi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-QrB46iokUuikgYmKgzkfdi">
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-6Qf9cAvfULpxVvN6Bkarz6" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-6Qf9cAvfULpxVvN6Bkarz6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-5ixvXtriKAdgjYt5i8mMZ4" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-5ixvXtriKAdgjYt5i8mMZ4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-DCMDiiXRcQYjfTTVUgqitc" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-DCMDiiXRcQYjfTTVUgqitc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QrB46iokUuikgYmKgzkfdi">
#         <div id="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-TPL7grkioNy3XqyJLHwZt2" class="ipyplot-content-div-QrB46iokUuikgYmKgzkfdi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QrB46iokUuikgYmKgzkfdi-TPL7grkioNy3XqyJLHwZt2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
rot1 = iaa.Affine(rotate=(-50, 20))

input_rot1 = rot1.augment_image(input_img)

images_list = [input_img, input_rot1]

labels = ['Original', 'Rotated Image']

ipyplot.plot_images(images_list, labels=labels, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DB6qibVpYxzNcqQ5Zw6QET {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DB6qibVpYxzNcqQ5Zw6QET {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DB6qibVpYxzNcqQ5Zw6QET {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DB6qibVpYxzNcqQ5Zw6QET:checked ~ #ipyplot-html-viewer-textarea-DB6qibVpYxzNcqQ5Zw6QET {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DB6qibVpYxzNcqQ5Zw6QET:checked + #ipyplot-html-viewer-label-DB6qibVpYxzNcqQ5Zw6QET:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-DB6qibVpYxzNcqQ5Zw6QET">
#         <label id="ipyplot-html-viewer-label-DB6qibVpYxzNcqQ5Zw6QET" for="ipyplot-html-viewer-toggle-DB6qibVpYxzNcqQ5Zw6QET">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-DB6qibVpYxzNcqQ5Zw6QET" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9em3BFqzWHHWBWJXaxjvAW">
#     <div class="ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW">
#         <div id="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-Mj9B9YxRfSEL7AzP5KQGsJ" class="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-Mj9B9YxRfSEL7AzP5KQGsJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW">
#         <div id="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-eopzsgcxzevnniaQVjE3La" class="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Rotated Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-eopzsgcxzevnniaQVjE3La">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9em3BFqzWHHWBWJXaxjvAW">
#     <div class="ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW">
#         <div id="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-Mj9B9YxRfSEL7AzP5KQGsJ" class="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-Mj9B9YxRfSEL7AzP5KQGsJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9em3BFqzWHHWBWJXaxjvAW">
#         <div id="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-eopzsgcxzevnniaQVjE3La" class="ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Rotated Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9em3BFqzWHHWBWJXaxjvAW-eopzsgcxzevnniaQVjE3La">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
noise = iaa.AdditiveGaussianNoise(10, 40)

input_noise = noise.augment_image(input_img)

images_list = [input_img, input_noise]

labels = ['Original', 'Gaussian Noise Image']

ipyplot.plot_images(images_list, labels=labels, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cN8W2jv46hM9VQeojn5kpg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cN8W2jv46hM9VQeojn5kpg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cN8W2jv46hM9VQeojn5kpg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cN8W2jv46hM9VQeojn5kpg:checked ~ #ipyplot-html-viewer-textarea-cN8W2jv46hM9VQeojn5kpg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cN8W2jv46hM9VQeojn5kpg:checked + #ipyplot-html-viewer-label-cN8W2jv46hM9VQeojn5kpg:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-cN8W2jv46hM9VQeojn5kpg">
#         <label id="ipyplot-html-viewer-label-cN8W2jv46hM9VQeojn5kpg" for="ipyplot-html-viewer-toggle-cN8W2jv46hM9VQeojn5kpg">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-cN8W2jv46hM9VQeojn5kpg" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kKWks5jBtQ9ZSjqBUu2DtV">
#     <div class="ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV">
#         <div id="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-2BaANTHDQn5uLUQ63mkCBL" class="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-2BaANTHDQn5uLUQ63mkCBL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV">
#         <div id="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-nNV9uPnWomaF2rP4i4Vr2D" class="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gaussian Noise Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-nNV9uPnWomaF2rP4i4Vr2D">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kKWks5jBtQ9ZSjqBUu2DtV">
#     <div class="ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV">
#         <div id="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-2BaANTHDQn5uLUQ63mkCBL" class="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-2BaANTHDQn5uLUQ63mkCBL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kKWks5jBtQ9ZSjqBUu2DtV">
#         <div id="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-nNV9uPnWomaF2rP4i4Vr2D" class="ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gaussian Noise Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kKWks5jBtQ9ZSjqBUu2DtV-nNV9uPnWomaF2rP4i4Vr2D">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # 仿射变换

# %%
elastic = iaa.ElasticTransformation(alpha=60.0, sigma=4.0)
polar = iaa.WithPolarWarping(iaa.CropAndPad(percent=(-0.2, 0.7)))
jigsaw = iaa.Jigsaw(nb_rows=20, nb_cols=15, max_steps=(3, 7))
input_elastic = elastic.augment_image(input_img)
input_polar = polar.augment_image(input_img)
input_jigsaw = jigsaw.augment_image(input_img)
images_list = [input_img, input_elastic, input_polar, input_jigsaw]
labels = ['Original', 'elastic', 'polar', 'jigsaw']
ipyplot.plot_images(images_list, labels=labels, img_width=180)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CVXGgzXdkMSPnrgnwPwWmD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CVXGgzXdkMSPnrgnwPwWmD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CVXGgzXdkMSPnrgnwPwWmD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CVXGgzXdkMSPnrgnwPwWmD:checked ~ #ipyplot-html-viewer-textarea-CVXGgzXdkMSPnrgnwPwWmD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CVXGgzXdkMSPnrgnwPwWmD:checked + #ipyplot-html-viewer-label-CVXGgzXdkMSPnrgnwPwWmD:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-CVXGgzXdkMSPnrgnwPwWmD">
#         <label id="ipyplot-html-viewer-label-CVXGgzXdkMSPnrgnwPwWmD" for="ipyplot-html-viewer-toggle-CVXGgzXdkMSPnrgnwPwWmD">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-CVXGgzXdkMSPnrgnwPwWmD" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FR8hADmrBGFStmQNkhqCBu">
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-JBgGncauruMmATTTTs9DUG" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-JBgGncauruMmATTTTs9DUG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-efr9k8XxY3Dj46y9BvRpWe" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">elastic</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-efr9k8XxY3Dj46y9BvRpWe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-eGpi5TpxKBoWi8JmWMgS3v" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">polar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-eGpi5TpxKBoWi8JmWMgS3v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-Spbs82cSrpDb7EkH7Mp55L" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">jigsaw</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-Spbs82cSrpDb7EkH7Mp55L">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FR8hADmrBGFStmQNkhqCBu">
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-JBgGncauruMmATTTTs9DUG" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-JBgGncauruMmATTTTs9DUG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-efr9k8XxY3Dj46y9BvRpWe" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">elastic</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-efr9k8XxY3Dj46y9BvRpWe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-eGpi5TpxKBoWi8JmWMgS3v" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">polar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-eGpi5TpxKBoWi8JmWMgS3v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FR8hADmrBGFStmQNkhqCBu">
#         <div id="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-Spbs82cSrpDb7EkH7Mp55L" class="ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">jigsaw</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FR8hADmrBGFStmQNkhqCBu-Spbs82cSrpDb7EkH7Mp55L">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # 改颜色 ChannelShuffle

# %%
from albumentations.augmentations.transforms import ChannelShuffle
import random
transform = ChannelShuffle(p=1.0)
random.seed(7)
augmented_image = transform(image=input_img)['image']
ipyplot.plot_images([augmented_image])

shuffle = iaa.ChannelShuffle()
shuffle_img=shuffle.augment_image(input_img)
ipyplot.plot_images([shuffle_img])
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-8RhDxmADcmD844PU9h6ZnR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8RhDxmADcmD844PU9h6ZnR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8RhDxmADcmD844PU9h6ZnR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8RhDxmADcmD844PU9h6ZnR:checked ~ #ipyplot-html-viewer-textarea-8RhDxmADcmD844PU9h6ZnR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8RhDxmADcmD844PU9h6ZnR:checked + #ipyplot-html-viewer-label-8RhDxmADcmD844PU9h6ZnR:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-8RhDxmADcmD844PU9h6ZnR">
#         <label id="ipyplot-html-viewer-label-8RhDxmADcmD844PU9h6ZnR" for="ipyplot-html-viewer-toggle-8RhDxmADcmD844PU9h6ZnR">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-8RhDxmADcmD844PU9h6ZnR" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-TB4gFuWBKVzAUTLyWFGsQf">
#     <div class="ipyplot-placeholder-div-TB4gFuWBKVzAUTLyWFGsQf">
#         <div id="ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf-hh6mZyySEqM7RSC5QBLBTV" class="ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf-hh6mZyySEqM7RSC5QBLBTV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-TB4gFuWBKVzAUTLyWFGsQf">
#     <div class="ipyplot-placeholder-div-TB4gFuWBKVzAUTLyWFGsQf">
#         <div id="ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf-hh6mZyySEqM7RSC5QBLBTV" class="ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TB4gFuWBKVzAUTLyWFGsQf-hh6mZyySEqM7RSC5QBLBTV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-UEWjdfG94hCtUp7SfwHtpn {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UEWjdfG94hCtUp7SfwHtpn {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UEWjdfG94hCtUp7SfwHtpn {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UEWjdfG94hCtUp7SfwHtpn:checked ~ #ipyplot-html-viewer-textarea-UEWjdfG94hCtUp7SfwHtpn {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UEWjdfG94hCtUp7SfwHtpn:checked + #ipyplot-html-viewer-label-UEWjdfG94hCtUp7SfwHtpn:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-UEWjdfG94hCtUp7SfwHtpn">
#         <label id="ipyplot-html-viewer-label-UEWjdfG94hCtUp7SfwHtpn" for="ipyplot-html-viewer-toggle-UEWjdfG94hCtUp7SfwHtpn">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-UEWjdfG94hCtUp7SfwHtpn" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3PxViFwNC32g5SifJQNdU8">
#     <div class="ipyplot-placeholder-div-3PxViFwNC32g5SifJQNdU8">
#         <div id="ipyplot-content-div-3PxViFwNC32g5SifJQNdU8-i6nfjKghRwxfx4HXtzeGoK" class="ipyplot-content-div-3PxViFwNC32g5SifJQNdU8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PxViFwNC32g5SifJQNdU8-i6nfjKghRwxfx4HXtzeGoK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3PxViFwNC32g5SifJQNdU8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3PxViFwNC32g5SifJQNdU8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3PxViFwNC32g5SifJQNdU8">
#     <div class="ipyplot-placeholder-div-3PxViFwNC32g5SifJQNdU8">
#         <div id="ipyplot-content-div-3PxViFwNC32g5SifJQNdU8-i6nfjKghRwxfx4HXtzeGoK" class="ipyplot-content-div-3PxViFwNC32g5SifJQNdU8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PxViFwNC32g5SifJQNdU8-i6nfjKghRwxfx4HXtzeGoK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
def change_channel(image, channel: int):
    im = image.copy()  # Copy the YUV image to an other one
    for i in range(im.shape[0]):
        for j in range(im.shape[1]):
            im[i, j, 1] = 0  # Set U to 0
            im[i, j, 2] = 0  
    return im


im1 = change_channel(input_img, 0)
im2 = change_channel(input_img, 1)
im3 = change_channel(input_img, 2)
ipyplot.plot_images([im1, im2, im3])
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ug7BP2XLCBgtCYNTXBhuk8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ug7BP2XLCBgtCYNTXBhuk8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ug7BP2XLCBgtCYNTXBhuk8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ug7BP2XLCBgtCYNTXBhuk8:checked ~ #ipyplot-html-viewer-textarea-Ug7BP2XLCBgtCYNTXBhuk8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ug7BP2XLCBgtCYNTXBhuk8:checked + #ipyplot-html-viewer-label-Ug7BP2XLCBgtCYNTXBhuk8:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Ug7BP2XLCBgtCYNTXBhuk8">
#         <label id="ipyplot-html-viewer-label-Ug7BP2XLCBgtCYNTXBhuk8" for="ipyplot-html-viewer-toggle-Ug7BP2XLCBgtCYNTXBhuk8">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Ug7BP2XLCBgtCYNTXBhuk8" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z7SbKCCzRKbRS24VecbDAB">
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-cCmKYtmnaGscd4Bz7u7snE" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-cCmKYtmnaGscd4Bz7u7snE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-Q7vHP5TH3h7ECDUFkmaNbP" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-Q7vHP5TH3h7ECDUFkmaNbP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-MAgTW5uoAAtxoRKUWeP3VK" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-MAgTW5uoAAtxoRKUWeP3VK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z7SbKCCzRKbRS24VecbDAB">
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-cCmKYtmnaGscd4Bz7u7snE" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-cCmKYtmnaGscd4Bz7u7snE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-Q7vHP5TH3h7ECDUFkmaNbP" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-Q7vHP5TH3h7ECDUFkmaNbP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z7SbKCCzRKbRS24VecbDAB">
#         <div id="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-MAgTW5uoAAtxoRKUWeP3VK" class="ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z7SbKCCzRKbRS24VecbDAB-MAgTW5uoAAtxoRKUWeP3VK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
